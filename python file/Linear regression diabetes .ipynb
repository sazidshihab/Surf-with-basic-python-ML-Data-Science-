# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as mat
import statsmodels.api as sat
import seaborn as sns
sns.set()

from sklearn.linear_model import LinearRegression
from scipy.stats import pearsonr

# %%
data = pd.read_csv('/Users/sazid/Downloads/diabetes[1].csv')

# %%
data.describe(include='all')
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
corr, p = pearsonr(data['Outcome'],data['Pregnancies'])
corr,p
# Out:
# (0.2218981530339849, 5.065127298055012e-10)

# %%
corr, p = pearsonr(data['Outcome'],data['Glucose'])
corr,p
# Out:
# (0.46658139830687284, 8.93543164529487e-43)

# %%
corr, p = pearsonr(data['Outcome'],data['BloodPressure'])
corr,p
# Out:
# (0.06506835955033241, 0.0715139000977645)

# %%
corr, p = pearsonr(data['Outcome'],data['SkinThickness'])
corr,p
# Out:
# (0.07475223191831909, 0.038347704820491685)

# %%
corr, p = pearsonr(data['Outcome'],data['Insulin'])
corr,p
# Out:
# (0.13054795488404708, 0.00028618646036033906)

# %%
corr, p = pearsonr(data['Outcome'],data['BMI'])
corr,p
# Out:
# (0.2926946626444437, 1.229807487312238e-16)

# %%
corr, p = pearsonr(data['Outcome'],data['DiabetesPedigreeFunction'])
corr,p
# Out:
# (0.17384406565295896, 1.2546070101489972e-06)

# %%
corr, p = pearsonr(data['Outcome'],data['Age'])
corr,p
# Out:
# (0.2383559830271963, 2.2099754606660333e-11)

# %%
data.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
data = data.drop(['BloodPressure','SkinThickness'], axis=1)

# %%
data
# Out:
#      Pregnancies  Glucose  Insulin   BMI  DiabetesPedigreeFunction  Age  \
# 0              6      148        0  33.6                     0.627   50
# 1              1       85        0  26.6                     0.351   31
# 2              8      183        0  23.3                     0.672   32
# 3              1       89       94  28.1                     0.167   21
# 4              0      137      168  43.1                     2.288   33
# ..           ...      ...      ...   ...                       ...  ...
# 763           10      101      180  32.9                     0.171   63
# 764            2      122        0  36.8                     0.340   27
# 765            5      121      112  26.2                     0.245   30
# 766            1      126        0  30.1                     0.349   47
# 767            1       93        0  30.4                     0.315   23
#
#      Outcome
# 0          1
# 1          0
# 2          1
# 3          0
# 4          1
# ..       ...
# ...

# %%
target = data['Outcome']

test = data.drop(['Outcome'], axis=1)

# %%
reg = LinearRegression()
reg.fit(test,target)
# Out:
# LinearRegression()

# %%
reg.score(test,target)
# Out:
# 0.295599002490301
